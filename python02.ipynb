# %% [markdown]
# pyton :bitwise operator
# ooperator are used to perform  operaton

# %%
a=10 #1010
b=4  #0100
print(a&b)
# Out:
# 0

# %% [markdown]
# bitbites operator
# bitbits AND = return 1 if both the bits are one else 0

# %% [markdown]
# bitwise or :  return 1 if either of bits is one else zero

# %%
a=10
b=4
print(a|b)
# Out:
# 14

# %% [markdown]
# bitwise not operator ;
# return one's complemnt of the number

# %%
a=10
print(~a)
# Out:
# -11

# %% [markdown]
# bitwise xor:
# return 1 if one of bit is one and other is zero

# %%
a=10
b=4
print(a^b)
# Out:
# 14

# %% [markdown]
# shift operator:
# this op is used to shift the bits of a number left to rigth
# thereby multipling or dividing
# bitwise right
# shift the bit of number to the right and fills zero on void left (fills one in the case of a negative num) as a result simaral effect on dividing a

# %%
a=10
print(a>>1)
print(a>>2)
# Out:
# 5
# 2

# %%
a=10
print(a<<1)
print(a<<2)
# Out:
# 20
# 40

# %% [markdown]
# bitwise left shift shift the bit of number to the left and fills zero and void right simiar effect as of multipling the number with power 2
